# %%
import sys
sys.path.append('../src')

# %%
from utils import economic_order_quantity
from utils import total_cost

# %%
# Case 1
setup_cost = 100
demand = 2000
holding_cost = 0.15
variable_cost = 1

eoq = economic_order_quantity(demand, setup_cost, holding_cost)
total = total_cost(demand, setup_cost, variable_cost, holding_cost, eoq)
print(f"Case 1: EOQ = {eoq}, Total Cost = {total}")
# Out:
# Case 1: EOQ = 1632.9931618554522, Total Cost = 2244.948974278318

# %%
# Case 2
variable_cost = 0.8
holding_cost = 0.15 * 0.8  # Adjusted holding cost based on variable cost

eoq = economic_order_quantity(demand, setup_cost, holding_cost)
total = total_cost(demand, setup_cost, variable_cost, holding_cost, eoq)
print(f"Case 2: EOQ = {eoq}, Total Cost = {total}")
# Out:
# Case 2: EOQ = 1825.7418583505537, Total Cost = 1819.0890230020664
